# %%
class Graph():
 
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)]
                      for row in range(vertices)]
 
    def print_solution(self, dist):
        print("Vertex \t Distance from Source")
        for node in range(self.V):
            print(node, "\t\t", dist[node])
 
    # A utility function to find the vertex with
    # minimum distance value, from the set of vertices
    # not yet included in shortest path tree
    def min_distance(self, dist, spt_set):
 
        
        min_start = 1e7
 
        # Search not nearest vertex not in the
        # shortest path tree
        for v in range(self.V):
            if dist[v] < min_start and spt_set[v] == False:
                min_start = dist[v]
                min_index = v
 
        return min_index
 
    # Function that implements Dijkstra's single source
    # shortest path algorithm for a graph represented
    # using adjacency matrix representation
    def dijkstra_shortestpath(self, src):
         
        dist = [1e7] * self.V
        dist[src] = 0
        spt_set = [False] * self.V
 
        for cout in range(self.V):
 
            # Pick the minimum distance vertex from
            # the set of vertices not yet processed.
            # u is always equal to src in first iteration
            u = self.min_distance(dist, spt_set)
 
            # Put the minimum distance vertex in the
            # shortest path tree
            spt_set[u] = True
 
            # Update dist value of the adjacent vertices
            # of the picked vertex only if the current
            # distance is greater than new distance and
            # the vertex in not in the shortest path tree
            for v in range(self.V):
                if (self.graph[u][v] > 0 and
                   spt_set[v] == False and
                   dist[v] > dist[u] + self.graph[u][v]):
                    dist[v] = dist[u] + self.graph[u][v]
 
        self.print_solution(dist)
 # Driver program
g=Graph(9)
g.graph = [[0, 4, 0, 0, 0, 0, 0, 8, 0],
           [4, 0, 8, 0, 0, 0, 0, 11, 0],
           [0, 8, 0, 7, 0, 4, 0, 0, 2],
           [0, 0, 7, 0, 9, 14, 0, 0, 0],
           [0, 0, 0, 9, 0, 10, 0, 0, 0],
           [0, 0, 4, 14, 10, 0, 2, 0, 0],
           [0, 0, 0, 0, 0, 2, 0, 1, 6],
           [8, 11, 0, 0, 0, 0, 1, 0, 7],
           [0, 0, 2, 0, 0, 0, 6, 7, 0]
           ]
print ("Start Point 7")
g.dijkstra_shortestpath(7)
print ("Start Point 0")
g.dijkstra_shortestpath(0)
# Out:
# Start Point 7
# Vertex 	 Distance from Source
# 0 		 8
# 1 		 11
# 2 		 7
# 3 		 14
# 4 		 13
# 5 		 3
# 6 		 1
# 7 		 0
# 8 		 7
# Start Point 0
# Vertex 	 Distance from Source
# 0 		 0
# 1 		 4
# 2 		 12
# 3 		 19
# 4 		 21
# 5 		 11
# 6 		 9
# 7 		 8
# 8 		 14

# %%
class Graph():
 
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)]
                      for row in range(vertices)]
 
    def print_solution(self, dist):
        print("Vertex \t Distance from Source")
        for node in range(self.V):
            print(node, "\t\t", dist[node])
 
    # A utility function to find the vertex with
    # minimum distance value, from the set of vertices
    # not yet included in shortest path tree
    def min_distance(self, dist, spt_set):
 
        
        min_start = 1e7
 
        # Search not nearest vertex not in the
        # shortest path tree
        for v in range(self.V):
            if dist[v] < min_start and spt_set[v] == False:
                min_start = dist[v]
                min_index = v
 
        return min_index
 
    # Function that implements Dijkstra's from all vertex
    
    
    def dijkstra_shortestpath(self):
        #for loop to make sure all the nodes are covered and calculate the shortest path.
        for i in range(self.V):
            src = i
        
            dist = [1e7] * self.V
            dist[src] = 0
            spt_set = [False] * self.V

            for cout in range(self.V):

                # Pick the minimum distance vertex from
                # the set of vertices not yet processed.
                # u is always equal to src in first iteration
                u = self.min_distance(dist, spt_set)

                # Put the minimum distance vertex in the
                # shortest path tree
                spt_set[u] = True

                # Update dist value of the adjacent vertices
                # of the picked vertex only if the current
                # distance is greater than new distance and
                # the vertex in not in the shortest path tree
                for v in range(self.V):
                    if (self.graph[u][v] > 0 and
                       spt_set[v] == False and
                       dist[v] > dist[u] + self.graph[u][v]):
                        dist[v] = dist[u] + self.graph[u][v]
            print("Shortest path From the Node", i)
            self.print_solution(dist)
 # Driver program
g=Graph(9)
g.graph = [[0, 4, 0, 0, 0, 0, 0, 8, 0],
           [4, 0, 8, 0, 0, 0, 0, 11, 0],
           [0, 8, 0, 7, 0, 4, 0, 0, 2],
           [0, 0, 7, 0, 9, 14, 0, 0, 0],
           [0, 0, 0, 9, 0, 10, 0, 0, 0],
           [0, 0, 4, 14, 10, 0, 2, 0, 0],
           [0, 0, 0, 0, 0, 2, 0, 1, 6],
           [8, 11, 0, 0, 0, 0, 1, 0, 7],
           [0, 0, 2, 0, 0, 0, 6, 7, 0]
           ]

g.dijkstra_shortestpath()
# Out:
# Shortest path From the Node 0
# Vertex 	 Distance from Source
# 0 		 0
# 1 		 4
# 2 		 12
# 3 		 19
# 4 		 21
# 5 		 11
# 6 		 9
# 7 		 8
# 8 		 14
# Shortest path From the Node 1
# Vertex 	 Distance from Source
# 0 		 4
# 1 		 0
# 2 		 8
# 3 		 15
# 4 		 22
# 5 		 12
# 6 		 12
# 7 		 11
# 8 		 10
# Shortest path From the Node 2
# Vertex 	 Distance from Source
# 0 		 12
# 1 		 8
# 2 		 0
# 3 		 7
# 4 		 14
# 5 		 4
# 6 		 6
# 7 		 7
# 8 		 2
# Shortest path From the Node 3
# Vertex 	 Distance from Source
# 0 		 19
# 1 		 15
# 2 		 7
# 3 		 0
# 4 		 9
# 5 		 11
# 6 		 13
# 7 		 14
# 8 		 9
# Shortest path From the Node 4
# Vertex 	 Distance from Source
# 0 		 21
# 1 		 22
# 2 		 14
# 3 		 9
# 4 		 0
# 5 		 10
# 6 		 12
# 7 		 13
# 8 		 16
# Shortest path From the Node 5
# Vertex 	 Distance from Source
# 0 		 11
# 1 		 12
# 2 		 4
# 3 		 11
# 4 		 10
# 5 		 0
# 6 		 2
# 7 		 3
# 8 		 6
# Shortest path From the Node 6
# Vertex 	 Distance from Source
# 0 		 9
# 1 		 12
# 2 		 6
# ...

# %%
# Number of vertices in the graph
V = 4
 
#A high value of inf is taken as input.
inf = 99999

def print_solution(dist):
    print("The Shortest path is :")
    for i in range(V):
        for j in range(V):
            if(dist[i][j] == inf):
                print("%7s" % ("inf"), end=" ")
            else:
                print("%7d\t" % (dist[i][j]), end=' ')
            if j == V-1:
                print()

#Floydwarshell algorithm function                
def floydWarshall_shortestpath(graph):
    
 
    dist = list(map(lambda i: list(map(lambda j: j, i)), graph))
 
   
    for k in range(V):
 
        
        for i in range(V):
 
            
            for j in range(V):
 
                
                dist[i][j] = min(dist[i][j],
                                 dist[i][k] + dist[k][j]
                                 )
    print_solution(dist)
 

 
# Driver's code
print("First Test Case")
graph = [[0, 5, inf, 10],
         [inf, 0, 3, inf],
         [inf, inf, 0,   1],
         [inf, inf, inf, 0]
         ]
  # Function call
floydWarshall_shortestpath(graph)
print("Second Test case")
graph2 = [[70, 15, inf, 20],
         [inf, 70, 30, inf],
         [inf, inf, 10,   15],
         [inf, inf, inf, 80]
         ]
  # Function call
floydWarshall_shortestpath(graph2)
# Out:
# First Test Case
# The Shortest path is :
#       0	       5	       8	       9
#     inf       0	       3	       4
#     inf     inf       0	       1
#     inf     inf     inf       0
# Second Test case
# The Shortest path is :
#      70	      15	      45	      20
#     inf      70	      30	      45
#     inf     inf      10	      15
#     inf     inf     inf      80
